# %%
from datetime import date,time,datetime
date.today()
date(2025,12,2)
time(8,10,3)
datetime.now()
# Out:
# datetime.datetime(2025, 12, 2, 11, 47, 17, 637060)

# %%
import os

os.getcwd()
# Out:
# 'D:\\T3_PY_B1'

# %%
pwd
# Out:
# 'D:\\T3_PY_B1'

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# 'D:\\'

# %%
os.mkdir('D:/Diya')

# %%
os.mkdir('D:/Diya/Diya25')

# %%
os.chdir('D:/Diya')

# %%
os.getcwd()
# Out:
# 'D:\\Diya'

# %%
os.listdir('C:')
# Out:
# ['$Recycle.Bin',
#  '$WinREAgent',
#  'boot',
#  'Config.Msi',
#  'DEMO',
#  'Documents and Settings',
#  'DumpStack.log',
#  'DumpStack.log.tmp',
#  'hiberfil.sys',
#  'inetpub',
#  'Insight Files',
#  'Intel',
#  'msdia80.dll',
#  'MSOCache',
#  'oraclexe',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Recovery',
#  'reflect_uninstall.log',
#  'RESULT',
#  'swapfile.sys',
#  'System Volume Information',
#  'TurboC++',
#  'Users',
#  'Windows',
#  'xampp']

# %%
import os

# %%
os.listdir('D:')
# Out:
# ['.ipynb_checkpoints',
#  '1.txt',
#  '2.txt',
#  '3.txt',
#  'city.txt',
#  'customer.txt',
#  'Eg1.txt',
#  'example.txt',
#  'example1.txt',
#  'f.txt',
#  'file1.txt',
#  'file_practice.ipynb',
#  'friends.txt',
#  'Lec1.ipynb',
#  'logfile.txt',
#  'mbox-short.txt',
#  'Module.ipynb',
#  'namelist.txt',
#  'python.txt',
#  'python1.txt',
#  'python2.txt',
#  'QB_SOLUTION_6,7,8-Copy1 (1).ipynb',
#  'sample.txt',
#  'sample1.txt',
#  'scores.txt',
#  'secretmessage.txt',
#  'Story.txt',
#  'Untitled.ipynb']

# %%
os.getcwd()
# Out:
# 'D:\\T3_PY_B1'

# %%
os.chdir('D:/Diya')

# %%
os.getcwd()
# Out:
# 'D:\\Diya'

# %%
f1 = open('file1.txt','w')
f2 = open('file2.txt','w')
f1.write('Hello')
f2.write('Welcome')
f1.close()
f2.close()

# %%
import os

# %%
os.listdir('D:/Diya')
# Out:
# ['Diya25', 'file1.txt', 'file2.txt']

# %%
os.remove('D:/Diya/file2.txt')

# %%
os.rmdir('D:/DIYA')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-11-029808f439ec> in <module>
# ----> 1 os.rmdir('D:/DIYA')
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'D:/DIYA'

# %%
os.rmdir('D:/Diya/Diya25')

# %%
os.getcwd()
# Out:
# 'D:\\Diya'

# %%
os.chdir('D:/T3_PY_B1')

# %%
os.rmdir('D:/Diya')
