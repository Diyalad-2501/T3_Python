# %%
import os

# %%
os.chdir('D:/T3_PY_B1')

# %%
# %%writefile calc.py
def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def div(a,b):
    print(a/b)
def mul(a,b):
    print(a*b)
x=10
y=15
# Out:
# Writing calc.py

# %%
import calc

# %%
print(calc.x)
# Out:
# 10

# %%
calc.add(3,5)
# Out:
# 8

# %%
import calc as c
c.mul(3,5)
# Out:
# 15

# %%
from calc import add
add(1,2)
sub(2,4)
# Out:
# 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7fc950b26f74> in <module>
#       1 from calc import add
#       2 add(1,2)
# ----> 3 sub(2,4)
#
# NameError: name 'sub' is not defined

# %%
from calc import *
print(x)
add(3,4)
sub(4,4)
# Out:
# 10
# 7
# 0

# %%
# %%writefile b2.py
def find(s , sub):
    l=len(sub)
    for i ,j in enumerate(s):
        if s[i:i+l]==sub:
            return i
        
def rfind(s,sub):
    l=len(sub)
    for i ,j in enumerate(s):
        if s[i:i+l]==sub:
            ans=i
    return ans

def count(s,sub):
    l=len(sub)
    c=0
    for i,j in enumerate(s):
        if s[i:i+l]==sub:
            c+=1
    return c
def first(s):
    return s.split()[0]
# Out:
# Writing b2.py

# %%
import b2 as b
b.rfind('aDiyaaaaaaaaaaaaaaaaaaa','a')
# Out:
# 22
