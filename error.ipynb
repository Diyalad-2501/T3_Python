# %%
print 'hello'
# Out:
#   File "<ipython-input-1-5a1ef41e7057>", line 1
#     print 'hello'
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('hello')?

# %%
iff 3>4:
    print('b1 is best')

# %%
for i in range(10):

# %%
class diya:

# %%
print('hi'

# %%
d={'A':3

# %%
fdfd

# %%
a='klk'
a+=1

# %%
int('k')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-baaa8222bd47> in <module>
# ----> 1 int('k')
#
# ValueError: invalid literal for int() with base 10: 'k'

# %%
l=[1]
print(l[90])

# %%
l=[9]
l.upper()

# %%
d={}
d['A']

# %%
f = open('eryt')

# %%
import vha

# %%
print(9/0)

# %%
f = open('namelist.txt','r')
c=0
for i in f:
    c+=1
    print(i)
    
    if c%5==0:
        s=input('Do you want to read more line (Y/N): ')
        
        if s=='N':
            break
# Out:
# Noble Pinkston
#
# Mavis Paola Shindler
#
# Fritz Kelly Mcgonigle
#
# Amy A. Snuggs
#
# Roselee Forbis
#
# Do you want to read more line (Y/N): Y
# Rebbeca Ribera
#
# Kim Sterling Reiher
#
# Stephany Bopp
#
# Alayna Moffet
#
# Patrick Linwood Letchworth
#
# Do you want to read more line (Y/N): Y
# Arica Westrich
#
# Henriette Thornell
#
# Claudio Lawhon
#
# Amy Ellen Illou
#
# Elisabeth Royer
#
# Do you want to read more line (Y/N): Y
# Micheline Sophie Franck
#
# Kenny Z. Pinckard
#
# Jennell Jozwiak
#
# Ignacia Rinke
#
# Morton G. Mielke
#
# Do you want to read more line (Y/N): N
